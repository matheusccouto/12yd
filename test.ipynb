# %%
from twelveyards.fotmob.client import FotMobClient

client = FotMobClient()

# %%
response = client.get(
    "leagues/77/overview/world-cup",
    params={"season": "2026"},
)

response["pageProps"]["fixtures"]["allMatches"]
# Out:
# [{'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/south-africa-vs-mexico/1einvt#4667751',
#   'id': '4667751',
#   'home': {'name': 'Mexico', 'shortName': 'Mexico', 'id': '6710'},
#   'away': {'name': 'South Africa', 'shortName': 'South Africa', 'id': '6316'},
#   'group': 'A',
#   'status': {'utcTime': '2026-06-11T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/south-korea-vs-czechia/273opa#4667752',
#   'id': '4667752',
#   'home': {'name': 'South Korea', 'shortName': 'South Korea', 'id': '7804'},
#   'away': {'name': 'Czechia', 'shortName': 'Czechia', 'id': '8496'},
#   'group': 'A',
#   'status': {'utcTime': '2026-06-12T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/canada-vs-bosnia-herzegovina/23f1qo#4667757',
#   'id': '4667757',
#   'home': {'name': 'Canada', 'shortName': 'Canada', 'id': '5810'},
#   'away': {'name': 'Bosnia and Herzegovina',
#    'shortName': 'Bosnia and Herzegovina',
#    'id': '10106'},
#   'group': 'B',
#   'status': {'utcTime': '2026-06-12T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/usa-vs-paraguay/1hr85j#4667771',
#   'id': '4667771',
#   'home': {'name': 'USA', 'shortName': 'USA', 'id': '6713'},
#   'away': {'name': 'Paraguay', 'shortName': 'Paraguay', 'id': '6724'},
#   'group': 'D',
#   'status': {'utcTime': '2026-06-13T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '4 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/qatar-vs-switzerland/1beswv#4667758',
#   'id': '4667758',
#   'home': {'name': 'Qatar', 'shortName': 'Qatar', 'id': '5902'},
#   'away': {'name': 'Switzerland', 'shortName': 'Switzerland', 'id': '6717'},
#   'group': 'B',
#   'status': {'utcTime': '2026-06-13T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/morocco-vs-brazil/1qr4gd#4667764',
#   'id': '4667764',
#   'home': {'name': 'Brazil', 'shortName': 'Brazil', 'id': '8256'},
#   'away': {'name': 'Morocco', 'shortName': 'Morocco', 'id': '6262'},
#   'group': 'C',
#   'status': {'utcTime': '2026-06-13T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/haiti-vs-scotland/1q0g2q#4667765',
#   'id': '4667765',
#   'home': {'name': 'Haiti', 'shortName': 'Haiti', 'id': '5934'},
#   'away': {'name': 'Scotland', 'shortName': 'Scotland', 'id': '8498'},
#   'group': 'C',
#   'status': {'utcTime': '2026-06-14T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/turkiye-vs-australia/1gr3uk#4667772',
#   'id': '4667772',
#   'home': {'name': 'Australia', 'shortName': 'Australia', 'id': '6716'},
#   'away': {'name': 'Turkiye', 'shortName': 'Turkiye', 'id': '6595'},
#   'group': 'D',
#   'status': {'utcTime': '2026-06-14T04:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/germany-vs-curacao/k77fsyu#4667777',
#   'id': '4667777',
#   'home': {'name': 'Germany', 'shortName': 'Germany', 'id': '8570'},
#   'away': {'name': 'Curacao', 'shortName': 'Curacao', 'id': '287981'},
#   'group': 'E',
#   'status': {'utcTime': '2026-06-14T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '7 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/netherlands-vs-japan/1hn72b#4667783',
#   'id': '4667783',
#   'home': {'name': 'Netherlands', 'shortName': 'Netherlands', 'id': '6708'},
#   'away': {'name': 'Japan', 'shortName': 'Japan', 'id': '6715'},
#   'group': 'F',
#   'status': {'utcTime': '2026-06-14T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/ecuador-vs-ivory-coast/1hl6kp#4667778',
#   'id': '4667778',
#   'home': {'name': 'Ivory Coast', 'shortName': 'Ivory Coast', 'id': '6709'},
#   'away': {'name': 'Ecuador', 'shortName': 'Ecuador', 'id': '6707'},
#   'group': 'E',
#   'status': {'utcTime': '2026-06-14T23:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/tunisia-vs-sweden/1x5290#4667784',
#   'id': '4667784',
#   'home': {'name': 'Sweden', 'shortName': 'Sweden', 'id': '8520'},
#   'away': {'name': 'Tunisia', 'shortName': 'Tunisia', 'id': '6719'},
#   'group': 'F',
#   'status': {'utcTime': '2026-06-15T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '5 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/cape-verde-vs-spain/1bbtuo#4667798',
#   'id': '4667798',
#   'home': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'away': {'name': 'Cape Verde', 'shortName': 'Cape Verde', 'id': '5888'},
#   'group': 'H',
#   'status': {'utcTime': '2026-06-15T16:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/belgium-vs-egypt/2u3bhg#4667790',
#   'id': '4667790',
#   'home': {'name': 'Belgium', 'shortName': 'Belgium', 'id': '8263'},
#   'away': {'name': 'Egypt', 'shortName': 'Egypt', 'id': '10255'},
#   'group': 'G',
#   'status': {'utcTime': '2026-06-15T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/uruguay-vs-saudi-arabia/1izuvb#4667799',
#   'id': '4667799',
#   'home': {'name': 'Saudi Arabia', 'shortName': 'Saudi Arabia', 'id': '7795'},
#   'away': {'name': 'Uruguay', 'shortName': 'Uruguay', 'id': '5796'},
#   'group': 'H',
#   'status': {'utcTime': '2026-06-15T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/new-zealand-vs-iran/1ar30l#4667791',
#   'id': '4667791',
#   'home': {'name': 'Iran', 'shortName': 'Iran', 'id': '6711'},
#   'away': {'name': 'New Zealand', 'shortName': 'New Zealand', 'id': '5820'},
#   'group': 'G',
#   'status': {'utcTime': '2026-06-16T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/senegal-vs-france/1f8fvo#4667804',
#   'id': '4667804',
#   'home': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'away': {'name': 'Senegal', 'shortName': 'Senegal', 'id': '6395'},
#   'group': 'I',
#   'status': {'utcTime': '2026-06-16T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/iraq-vs-norway/1oz68o#4667805',
#   'id': '4667805',
#   'home': {'name': 'Iraq', 'shortName': 'Iraq', 'id': '5819'},
#   'away': {'name': 'Norway', 'shortName': 'Norway', 'id': '8492'},
#   'group': 'I',
#   'status': {'utcTime': '2026-06-16T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/algeria-vs-argentina/1ehtqa#4667812',
#   'id': '4667812',
#   'home': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'away': {'name': 'Algeria', 'shortName': 'Algeria', 'id': '6317'},
#   'group': 'J',
#   'status': {'utcTime': '2026-06-17T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/jordan-vs-austria/1my603#4667813',
#   'id': '4667813',
#   'home': {'name': 'Austria', 'shortName': 'Austria', 'id': '8255'},
#   'away': {'name': 'Jordan', 'shortName': 'Jordan', 'id': '5816'},
#   'group': 'J',
#   'status': {'utcTime': '2026-06-17T04:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/dr-congo-vs-portugal/1s6g4o#4667819',
#   'id': '4667819',
#   'home': {'name': 'Portugal', 'shortName': 'Portugal', 'id': '8361'},
#   'away': {'name': 'DR Congo', 'shortName': 'DR Congo', 'id': '6321'},
#   'group': 'K',
#   'status': {'utcTime': '2026-06-17T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/england-vs-croatia/2viayw#4667825',
#   'id': '4667825',
#   'home': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'away': {'name': 'Croatia', 'shortName': 'Croatia', 'id': '10155'},
#   'group': 'L',
#   'status': {'utcTime': '2026-06-17T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '4 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/panama-vs-ghana/1bjek0#4667826',
#   'id': '4667826',
#   'home': {'name': 'Ghana', 'shortName': 'Ghana', 'id': '6714'},
#   'away': {'name': 'Panama', 'shortName': 'Panama', 'id': '5922'},
#   'group': 'L',
#   'status': {'utcTime': '2026-06-17T23:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1',
#   'roundName': 1,
#   'pageUrl': '/matches/colombia-vs-uzbekistan/2dm7x9#4667820',
#   'id': '4667820',
#   'home': {'name': 'Uzbekistan', 'shortName': 'Uzbekistan', 'id': '8700'},
#   'away': {'name': 'Colombia', 'shortName': 'Colombia', 'id': '8258'},
#   'group': 'K',
#   'status': {'utcTime': '2026-06-18T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/south-africa-vs-czechia/1tbjja#4667753',
#   'id': '4667753',
#   'home': {'name': 'Czechia', 'shortName': 'Czechia', 'id': '8496'},
#   'away': {'name': 'South Africa', 'shortName': 'South Africa', 'id': '6316'},
#   'group': 'A',
#   'status': {'utcTime': '2026-06-18T16:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/switzerland-vs-bosnia-herzegovina/2c9awx#4667759',
#   'id': '4667759',
#   'home': {'name': 'Switzerland', 'shortName': 'Switzerland', 'id': '6717'},
#   'away': {'name': 'Bosnia and Herzegovina',
#    'shortName': 'Bosnia and Herzegovina',
#    'id': '10106'},
#   'group': 'B',
#   'status': {'utcTime': '2026-06-18T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '4 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/canada-vs-qatar/14u9ym#4667760',
#   'id': '4667760',
#   'home': {'name': 'Canada', 'shortName': 'Canada', 'id': '5810'},
#   'away': {'name': 'Qatar', 'shortName': 'Qatar', 'id': '5902'},
#   'group': 'B',
#   'status': {'utcTime': '2026-06-18T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '6 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/mexico-vs-south-korea/1qpvav#4667754',
#   'id': '4667754',
#   'home': {'name': 'Mexico', 'shortName': 'Mexico', 'id': '6710'},
#   'away': {'name': 'South Korea', 'shortName': 'South Korea', 'id': '7804'},
#   'group': 'A',
#   'status': {'utcTime': '2026-06-19T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/usa-vs-australia/1hox83#4667774',
#   'id': '4667774',
#   'home': {'name': 'USA', 'shortName': 'USA', 'id': '6713'},
#   'away': {'name': 'Australia', 'shortName': 'Australia', 'id': '6716'},
#   'group': 'D',
#   'status': {'utcTime': '2026-06-19T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/morocco-vs-scotland/1sv292#4667766',
#   'id': '4667766',
#   'home': {'name': 'Scotland', 'shortName': 'Scotland', 'id': '8498'},
#   'away': {'name': 'Morocco', 'shortName': 'Morocco', 'id': '6262'},
#   'group': 'C',
#   'status': {'utcTime': '2026-06-19T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/haiti-vs-brazil/1ny7ix#4667767',
#   'id': '4667767',
#   'home': {'name': 'Brazil', 'shortName': 'Brazil', 'id': '8256'},
#   'away': {'name': 'Haiti', 'shortName': 'Haiti', 'id': '5934'},
#   'group': 'C',
#   'status': {'utcTime': '2026-06-20T00:30:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/turkiye-vs-paraguay/1gte1s#4667773',
#   'id': '4667773',
#   'home': {'name': 'Turkiye', 'shortName': 'Turkiye', 'id': '6595'},
#   'away': {'name': 'Paraguay', 'shortName': 'Paraguay', 'id': '6724'},
#   'group': 'D',
#   'status': {'utcTime': '2026-06-20T03:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/netherlands-vs-sweden/1x1gy6#4667786',
#   'id': '4667786',
#   'home': {'name': 'Netherlands', 'shortName': 'Netherlands', 'id': '6708'},
#   'away': {'name': 'Sweden', 'shortName': 'Sweden', 'id': '8520'},
#   'group': 'F',
#   'status': {'utcTime': '2026-06-20T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '5 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/ivory-coast-vs-germany/1xi59e#4667780',
#   'id': '4667780',
#   'home': {'name': 'Germany', 'shortName': 'Germany', 'id': '8570'},
#   'away': {'name': 'Ivory Coast', 'shortName': 'Ivory Coast', 'id': '6709'},
#   'group': 'E',
#   'status': {'utcTime': '2026-06-20T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/ecuador-vs-curacao/jy3jhs3#4667779',
#   'id': '4667779',
#   'home': {'name': 'Ecuador', 'shortName': 'Ecuador', 'id': '6707'},
#   'away': {'name': 'Curacao', 'shortName': 'Curacao', 'id': '287981'},
#   'group': 'E',
#   'status': {'utcTime': '2026-06-21T00:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/japan-vs-tunisia/1hqd1q#4667785',
#   'id': '4667785',
#   'home': {'name': 'Tunisia', 'shortName': 'Tunisia', 'id': '6719'},
#   'away': {'name': 'Japan', 'shortName': 'Japan', 'id': '6715'},
#   'group': 'F',
#   'status': {'utcTime': '2026-06-21T04:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/spain-vs-saudi-arabia/1qq6ht#4667801',
#   'id': '4667801',
#   'home': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'away': {'name': 'Saudi Arabia', 'shortName': 'Saudi Arabia', 'id': '7795'},
#   'group': 'H',
#   'status': {'utcTime': '2026-06-21T16:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '4 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/iran-vs-belgium/1ur91k#4667793',
#   'id': '4667793',
#   'home': {'name': 'Belgium', 'shortName': 'Belgium', 'id': '8263'},
#   'away': {'name': 'Iran', 'shortName': 'Iran', 'id': '6711'},
#   'group': 'G',
#   'status': {'utcTime': '2026-06-21T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/uruguay-vs-cape-verde/14n97e#4667800',
#   'id': '4667800',
#   'home': {'name': 'Uruguay', 'shortName': 'Uruguay', 'id': '5796'},
#   'away': {'name': 'Cape Verde', 'shortName': 'Cape Verde', 'id': '5888'},
#   'group': 'H',
#   'status': {'utcTime': '2026-06-21T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/new-zealand-vs-egypt/24xk7y#4667792',
#   'id': '4667792',
#   'home': {'name': 'New Zealand', 'shortName': 'New Zealand', 'id': '5820'},
#   'away': {'name': 'Egypt', 'shortName': 'Egypt', 'id': '10255'},
#   'group': 'G',
#   'status': {'utcTime': '2026-06-22T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/argentina-vs-austria/1un2w8#4667815',
#   'id': '4667815',
#   'home': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'away': {'name': 'Austria', 'shortName': 'Austria', 'id': '8255'},
#   'group': 'J',
#   'status': {'utcTime': '2026-06-22T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/iraq-vs-france/1au1fo#4667807',
#   'id': '4667807',
#   'home': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'away': {'name': 'Iraq', 'shortName': 'Iraq', 'id': '5819'},
#   'group': 'I',
#   'status': {'utcTime': '2026-06-22T21:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/senegal-vs-norway/1tzewo#4667806',
#   'id': '4667806',
#   'home': {'name': 'Norway', 'shortName': 'Norway', 'id': '8492'},
#   'away': {'name': 'Senegal', 'shortName': 'Senegal', 'id': '6395'},
#   'group': 'I',
#   'status': {'utcTime': '2026-06-23T00:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/jordan-vs-algeria/17tvf0#4667814',
#   'id': '4667814',
#   'home': {'name': 'Jordan', 'shortName': 'Jordan', 'id': '5816'},
#   'away': {'name': 'Algeria', 'shortName': 'Algeria', 'id': '6317'},
#   'group': 'J',
#   'status': {'utcTime': '2026-06-23T03:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/portugal-vs-uzbekistan/2enrsr#4667822',
#   'id': '4667822',
#   'home': {'name': 'Portugal', 'shortName': 'Portugal', 'id': '8361'},
#   'away': {'name': 'Uzbekistan', 'shortName': 'Uzbekistan', 'id': '8700'},
#   'group': 'K',
#   'status': {'utcTime': '2026-06-23T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '5 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/ghana-vs-england/1wtyve#4667828',
#   'id': '4667828',
#   'home': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'away': {'name': 'Ghana', 'shortName': 'Ghana', 'id': '6714'},
#   'group': 'L',
#   'status': {'utcTime': '2026-06-23T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/panama-vs-croatia/24y93x#4667827',
#   'id': '4667827',
#   'home': {'name': 'Panama', 'shortName': 'Panama', 'id': '5922'},
#   'away': {'name': 'Croatia', 'shortName': 'Croatia', 'id': '10155'},
#   'group': 'L',
#   'status': {'utcTime': '2026-06-23T23:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '2',
#   'roundName': 2,
#   'pageUrl': '/matches/dr-congo-vs-colombia/1ra58w#4667821',
#   'id': '4667821',
#   'home': {'name': 'Colombia', 'shortName': 'Colombia', 'id': '8258'},
#   'away': {'name': 'DR Congo', 'shortName': 'DR Congo', 'id': '6321'},
#   'group': 'K',
#   'status': {'utcTime': '2026-06-24T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/qatar-vs-bosnia-herzegovina/24aiya#4667762',
#   'id': '4667762',
#   'home': {'name': 'Bosnia and Herzegovina',
#    'shortName': 'Bosnia and Herzegovina',
#    'id': '10106'},
#   'away': {'name': 'Qatar', 'shortName': 'Qatar', 'id': '5902'},
#   'group': 'B',
#   'status': {'utcTime': '2026-06-24T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/canada-vs-switzerland/1aq0cl#4667761',
#   'id': '4667761',
#   'home': {'name': 'Switzerland', 'shortName': 'Switzerland', 'id': '6717'},
#   'away': {'name': 'Canada', 'shortName': 'Canada', 'id': '5810'},
#   'group': 'B',
#   'status': {'utcTime': '2026-06-24T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/haiti-vs-morocco/18aaq8#4667769',
#   'id': '4667769',
#   'home': {'name': 'Morocco', 'shortName': 'Morocco', 'id': '6262'},
#   'away': {'name': 'Haiti', 'shortName': 'Haiti', 'id': '5934'},
#   'group': 'C',
#   'status': {'utcTime': '2026-06-24T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '4 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/brazil-vs-scotland/2bkifh#4667768',
#   'id': '4667768',
#   'home': {'name': 'Scotland', 'shortName': 'Scotland', 'id': '8498'},
#   'away': {'name': 'Brazil', 'shortName': 'Brazil', 'id': '8256'},
#   'group': 'C',
#   'status': {'utcTime': '2026-06-24T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/mexico-vs-czechia/1wualx#4667755',
#   'id': '4667755',
#   'home': {'name': 'Czechia', 'shortName': 'Czechia', 'id': '8496'},
#   'away': {'name': 'Mexico', 'shortName': 'Mexico', 'id': '6710'},
#   'group': 'A',
#   'status': {'utcTime': '2026-06-25T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/south-africa-vs-south-korea/1ncyls#4667756',
#   'id': '4667756',
#   'home': {'name': 'South Africa', 'shortName': 'South Africa', 'id': '6316'},
#   'away': {'name': 'South Korea', 'shortName': 'South Korea', 'id': '7804'},
#   'group': 'A',
#   'status': {'utcTime': '2026-06-25T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/ivory-coast-vs-curacao/jy3w4js#4667782',
#   'id': '4667782',
#   'home': {'name': 'Curacao', 'shortName': 'Curacao', 'id': '287981'},
#   'away': {'name': 'Ivory Coast', 'shortName': 'Ivory Coast', 'id': '6709'},
#   'group': 'E',
#   'status': {'utcTime': '2026-06-25T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/ecuador-vs-germany/1xhhol#4667781',
#   'id': '4667781',
#   'home': {'name': 'Ecuador', 'shortName': 'Ecuador', 'id': '6707'},
#   'away': {'name': 'Germany', 'shortName': 'Germany', 'id': '8570'},
#   'group': 'E',
#   'status': {'utcTime': '2026-06-25T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/japan-vs-sweden/1x3r7y#4667788',
#   'id': '4667788',
#   'home': {'name': 'Japan', 'shortName': 'Japan', 'id': '6715'},
#   'away': {'name': 'Sweden', 'shortName': 'Sweden', 'id': '8520'},
#   'group': 'F',
#   'status': {'utcTime': '2026-06-25T23:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/netherlands-vs-tunisia/1hoci5#4667787',
#   'id': '4667787',
#   'home': {'name': 'Tunisia', 'shortName': 'Tunisia', 'id': '6719'},
#   'away': {'name': 'Netherlands', 'shortName': 'Netherlands', 'id': '6708'},
#   'group': 'F',
#   'status': {'utcTime': '2026-06-25T23:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/australia-vs-paraguay/1hs39g#4667776',
#   'id': '4667776',
#   'home': {'name': 'Paraguay', 'shortName': 'Paraguay', 'id': '6724'},
#   'away': {'name': 'Australia', 'shortName': 'Australia', 'id': '6716'},
#   'group': 'D',
#   'status': {'utcTime': '2026-06-26T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/turkiye-vs-usa/1gq91b#4667775',
#   'id': '4667775',
#   'home': {'name': 'Turkiye', 'shortName': 'Turkiye', 'id': '6595'},
#   'away': {'name': 'USA', 'shortName': 'USA', 'id': '6713'},
#   'group': 'D',
#   'status': {'utcTime': '2026-06-26T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/france-vs-norway/1wx88k#4667808',
#   'id': '4667808',
#   'home': {'name': 'Norway', 'shortName': 'Norway', 'id': '8492'},
#   'away': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'group': 'I',
#   'status': {'utcTime': '2026-06-26T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/iraq-vs-senegal/18f0co#4667809',
#   'id': '4667809',
#   'home': {'name': 'Senegal', 'shortName': 'Senegal', 'id': '6395'},
#   'away': {'name': 'Iraq', 'shortName': 'Iraq', 'id': '5819'},
#   'group': 'I',
#   'status': {'utcTime': '2026-06-26T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '5 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/cape-verde-vs-saudi-arabia/1jqqyp#4667803',
#   'id': '4667803',
#   'home': {'name': 'Cape Verde', 'shortName': 'Cape Verde', 'id': '5888'},
#   'away': {'name': 'Saudi Arabia', 'shortName': 'Saudi Arabia', 'id': '7795'},
#   'group': 'H',
#   'status': {'utcTime': '2026-06-27T00:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/uruguay-vs-spain/1an22i#4667802',
#   'id': '4667802',
#   'home': {'name': 'Uruguay', 'shortName': 'Uruguay', 'id': '5796'},
#   'away': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'group': 'H',
#   'status': {'utcTime': '2026-06-27T00:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/iran-vs-egypt/2dp33g#4667795',
#   'id': '4667795',
#   'home': {'name': 'Egypt', 'shortName': 'Egypt', 'id': '10255'},
#   'away': {'name': 'Iran', 'shortName': 'Iran', 'id': '6711'},
#   'group': 'G',
#   'status': {'utcTime': '2026-06-27T03:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/new-zealand-vs-belgium/1n1sct#4667794',
#   'id': '4667794',
#   'home': {'name': 'New Zealand', 'shortName': 'New Zealand', 'id': '5820'},
#   'away': {'name': 'Belgium', 'shortName': 'Belgium', 'id': '8263'},
#   'group': 'G',
#   'status': {'utcTime': '2026-06-27T03:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 5',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/ghana-vs-croatia/2cpwux#4667830',
#   'id': '4667830',
#   'home': {'name': 'Croatia', 'shortName': 'Croatia', 'id': '10155'},
#   'away': {'name': 'Ghana', 'shortName': 'Ghana', 'id': '6714'},
#   'group': 'L',
#   'status': {'utcTime': '2026-06-27T21:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/panama-vs-england/1pukme#4667829',
#   'id': '4667829',
#   'home': {'name': 'Panama', 'shortName': 'Panama', 'id': '5922'},
#   'away': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'group': 'L',
#   'status': {'utcTime': '2026-06-27T21:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/colombia-vs-portugal/2a883f#4667823',
#   'id': '4667823',
#   'home': {'name': 'Colombia', 'shortName': 'Colombia', 'id': '8258'},
#   'away': {'name': 'Portugal', 'shortName': 'Portugal', 'id': '8361'},
#   'group': 'K',
#   'status': {'utcTime': '2026-06-27T23:30:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/dr-congo-vs-uzbekistan/1v6daf#4667824',
#   'id': '4667824',
#   'home': {'name': 'DR Congo', 'shortName': 'DR Congo', 'id': '6321'},
#   'away': {'name': 'Uzbekistan', 'shortName': 'Uzbekistan', 'id': '8700'},
#   'group': 'K',
#   'status': {'utcTime': '2026-06-27T23:30:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/algeria-vs-austria/1r7yil#4667817',
#   'id': '4667817',
#   'home': {'name': 'Algeria', 'shortName': 'Algeria', 'id': '6317'},
#   'away': {'name': 'Austria', 'shortName': 'Austria', 'id': '8255'},
#   'group': 'J',
#   'status': {'utcTime': '2026-06-28T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '3',
#   'roundName': 3,
#   'pageUrl': '/matches/jordan-vs-argentina/1aoo0p#4667816',
#   'id': '4667816',
#   'home': {'name': 'Jordan', 'shortName': 'Jordan', 'id': '5816'},
#   'away': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'group': 'J',
#   'status': {'utcTime': '2026-06-28T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/canada-vs-south-africa/17s1wd#4653705',
#   'id': '4653705',
#   'home': {'name': 'South Africa', 'shortName': 'South Africa', 'id': '6316'},
#   'away': {'name': 'Canada', 'shortName': 'Canada', 'id': '5810'},
#   'status': {'utcTime': '2026-06-28T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/japan-vs-brazil/1uqadm#4653711',
#   'id': '4653711',
#   'home': {'name': 'Brazil', 'shortName': 'Brazil', 'id': '8256'},
#   'away': {'name': 'Japan', 'shortName': 'Japan', 'id': '6715'},
#   'status': {'utcTime': '2026-06-29T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/paraguay-vs-germany/1xn26z#4653703',
#   'id': '4653703',
#   'home': {'name': 'Germany', 'shortName': 'Germany', 'id': '8570'},
#   'away': {'name': 'Paraguay', 'shortName': 'Paraguay', 'id': '6724'},
#   'status': {'utcTime': '2026-06-29T20:30:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'Pen',
#     'shortKey': 'penalties_short',
#     'long': 'After penalties',
#     'longKey': 'afterpenalties'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/morocco-vs-netherlands/1e327v#4653706',
#   'id': '4653706',
#   'home': {'name': 'Netherlands', 'shortName': 'Netherlands', 'id': '6708'},
#   'away': {'name': 'Morocco', 'shortName': 'Morocco', 'id': '6262'},
#   'status': {'utcTime': '2026-06-30T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'Pen',
#     'shortKey': 'penalties_short',
#     'long': 'After penalties',
#     'longKey': 'afterpenalties'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/ivory-coast-vs-norway/1wsny5#4653712',
#   'id': '4653712',
#   'home': {'name': 'Ivory Coast', 'shortName': 'Ivory Coast', 'id': '6709'},
#   'away': {'name': 'Norway', 'shortName': 'Norway', 'id': '8492'},
#   'status': {'utcTime': '2026-06-30T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/france-vs-sweden/1x6dai#4653704',
#   'id': '4653704',
#   'home': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'away': {'name': 'Sweden', 'shortName': 'Sweden', 'id': '8520'},
#   'status': {'utcTime': '2026-06-30T21:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/ecuador-vs-mexico/1hlgxf#4653713',
#   'id': '4653713',
#   'home': {'name': 'Mexico', 'shortName': 'Mexico', 'id': '6710'},
#   'away': {'name': 'Ecuador', 'shortName': 'Ecuador', 'id': '6707'},
#   'status': {'utcTime': '2026-07-01T02:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/dr-congo-vs-england/1tbjj5#4653714',
#   'id': '4653714',
#   'home': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'away': {'name': 'DR Congo', 'shortName': 'DR Congo', 'id': '6321'},
#   'status': {'utcTime': '2026-07-01T16:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/senegal-vs-belgium/1rywdm#4653710',
#   'id': '4653710',
#   'home': {'name': 'Belgium', 'shortName': 'Belgium', 'id': '8263'},
#   'away': {'name': 'Senegal', 'shortName': 'Senegal', 'id': '6395'},
#   'status': {'utcTime': '2026-07-01T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'AET',
#     'shortKey': 'afterextratime_short',
#     'long': 'After extra time',
#     'longKey': 'afterextra'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/usa-vs-bosnia-herzegovina/2c7uzr#4653709',
#   'id': '4653709',
#   'home': {'name': 'USA', 'shortName': 'USA', 'id': '6713'},
#   'away': {'name': 'Bosnia and Herzegovina',
#    'shortName': 'Bosnia and Herzegovina',
#    'id': '10106'},
#   'status': {'utcTime': '2026-07-02T00:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/spain-vs-austria/1urklb#4653708',
#   'id': '4653708',
#   'home': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'away': {'name': 'Austria', 'shortName': 'Austria', 'id': '8255'},
#   'status': {'utcTime': '2026-07-02T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/portugal-vs-croatia/2u2izf#4653707',
#   'id': '4653707',
#   'home': {'name': 'Portugal', 'shortName': 'Portugal', 'id': '8361'},
#   'away': {'name': 'Croatia', 'shortName': 'Croatia', 'id': '10155'},
#   'status': {'utcTime': '2026-07-02T23:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/algeria-vs-switzerland/1ekwbo#4653717',
#   'id': '4653717',
#   'home': {'name': 'Switzerland', 'shortName': 'Switzerland', 'id': '6717'},
#   'away': {'name': 'Algeria', 'shortName': 'Algeria', 'id': '6317'},
#   'status': {'utcTime': '2026-07-03T03:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/australia-vs-egypt/2dqwke#4653716',
#   'id': '4653716',
#   'home': {'name': 'Australia', 'shortName': 'Australia', 'id': '6716'},
#   'away': {'name': 'Egypt', 'shortName': 'Egypt', 'id': '10255'},
#   'status': {'utcTime': '2026-07-03T18:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'Pen',
#     'shortKey': 'penalties_short',
#     'long': 'After penalties',
#     'longKey': 'afterpenalties'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/cape-verde-vs-argentina/1b81pp#4653715',
#   'id': '4653715',
#   'home': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'away': {'name': 'Cape Verde', 'shortName': 'Cape Verde', 'id': '5888'},
#   'status': {'utcTime': '2026-07-03T22:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'AET',
#     'shortKey': 'afterextratime_short',
#     'long': 'After extra time',
#     'longKey': 'afterextra'}}},
#  {'round': '1/16',
#   'roundName': 'Round of 32',
#   'pageUrl': '/matches/ghana-vs-colombia/1uqlxk#4653718',
#   'id': '4653718',
#   'home': {'name': 'Colombia', 'shortName': 'Colombia', 'id': '8258'},
#   'away': {'name': 'Ghana', 'shortName': 'Ghana', 'id': '6714'},
#   'status': {'utcTime': '2026-07-04T01:30:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/canada-vs-morocco/17e1pm#4653843',
#   'id': '4653843',
#   'home': {'name': 'Canada', 'shortName': 'Canada', 'id': '5810'},
#   'away': {'name': 'Morocco', 'shortName': 'Morocco', 'id': '6262'},
#   'status': {'utcTime': '2026-07-04T17:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/france-vs-paraguay/1hu3vk#4653842',
#   'id': '4653842',
#   'home': {'name': 'Paraguay', 'shortName': 'Paraguay', 'id': '6724'},
#   'away': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'status': {'utcTime': '2026-07-04T21:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/brazil-vs-norway/2bicve#4653846',
#   'id': '4653846',
#   'home': {'name': 'Brazil', 'shortName': 'Brazil', 'id': '8256'},
#   'away': {'name': 'Norway', 'shortName': 'Norway', 'id': '8492'},
#   'status': {'utcTime': '2026-07-05T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/mexico-vs-england/1wsny4#4653847',
#   'id': '4653847',
#   'home': {'name': 'Mexico', 'shortName': 'Mexico', 'id': '6710'},
#   'away': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'status': {'utcTime': '2026-07-06T01:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/spain-vs-portugal/1vppuu#4653844',
#   'id': '4653844',
#   'home': {'name': 'Portugal', 'shortName': 'Portugal', 'id': '8361'},
#   'away': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'status': {'utcTime': '2026-07-06T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/usa-vs-belgium/1urw5j#4653845',
#   'id': '4653845',
#   'home': {'name': 'USA', 'shortName': 'USA', 'id': '6713'},
#   'away': {'name': 'Belgium', 'shortName': 'Belgium', 'id': '8263'},
#   'status': {'utcTime': '2026-07-07T00:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/argentina-vs-egypt/2dn9n7#4653848',
#   'id': '4653848',
#   'home': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'away': {'name': 'Egypt', 'shortName': 'Egypt', 'id': '10255'},
#   'status': {'utcTime': '2026-07-07T16:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/8',
#   'roundName': 'Round of 16',
#   'pageUrl': '/matches/switzerland-vs-colombia/1urkle#4653849',
#   'id': '4653849',
#   'home': {'name': 'Switzerland', 'shortName': 'Switzerland', 'id': '6717'},
#   'away': {'name': 'Colombia', 'shortName': 'Colombia', 'id': '8258'},
#   'status': {'utcTime': '2026-07-07T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'Pen',
#     'shortKey': 'penalties_short',
#     'long': 'After penalties',
#     'longKey': 'afterpenalties'}}},
#  {'round': '1/4',
#   'roundName': 'Quarter-Finals',
#   'pageUrl': '/matches/morocco-vs-france/1e78fs#4653851',
#   'id': '4653851',
#   'home': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'away': {'name': 'Morocco', 'shortName': 'Morocco', 'id': '6262'},
#   'status': {'utcTime': '2026-07-09T20:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/4',
#   'roundName': 'Quarter-Finals',
#   'pageUrl': '/matches/spain-vs-belgium/1uu52b#4653853',
#   'id': '4653853',
#   'home': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'away': {'name': 'Belgium', 'shortName': 'Belgium', 'id': '8263'},
#   'status': {'utcTime': '2026-07-10T19:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'round': '1/4',
#   'roundName': 'Quarter-Finals',
#   'pageUrl': '/matches/england-vs-norway/2dvb4w#4653852',
#   'id': '4653852',
#   'home': {'name': 'Norway', 'shortName': 'Norway', 'id': '8492'},
#   'away': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'status': {'utcTime': '2026-07-11T21:00:00Z',
#    'timezone': 'UTC',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'AET',
#     'shortKey': 'afterextratime_short',
#     'long': 'After extra time',
#     'longKey': 'afterextra'}}},
#  {'round': '1/4',
#   'roundName': 'Quarter-Finals',
#   'pageUrl': '/matches/argentina-vs-switzerland/1hn72d#4653854',
#   'id': '4653854',
#   'home': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'away': {'name': 'Switzerland', 'shortName': 'Switzerland', 'id': '6717'},
#   'status': {'utcTime': '2026-07-12T01:00:00.000Z',
#    'numberOfAwayRedCards': 1,
#    'halfs': {'firstHalfStarted': '12.07.2026 03:00:43',
#     'secondHalfStarted': '12.07.2026 04:06:24',
#     'firstExtraHalfStarted': '12.07.2026 05:05:47',
#     'secondExtraHalfStarted': '12.07.2026 05:25:25'},
#    'periodLength': 45,
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'awarded': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'AET',
#     'shortKey': 'afterextratime_short',
#     'long': 'After extra time',
#     'longKey': 'afterextra'}}},
#  {'round': '1/2',
#   'roundName': 'Semi-Finals',
#   'pageUrl': '/matches/spain-vs-france/1hsydl#4653855',
#   'id': '4653855',
#   'home': {'name': 'France', 'shortName': 'France', 'id': '6723'},
#   'away': {'name': 'Spain', 'shortName': 'Spain', 'id': '6720'},
#   'status': {'utcTime': '2026-07-14T19:00:00Z',
#    'timezone': 'UTC',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'round': '1/2',
#   'roundName': 'Semi-Finals',
#   'pageUrl': '/matches/argentina-vs-england/1wrd1a#4653856',
#   'id': '4653856',
#   'home': {'name': 'England', 'shortName': 'England', 'id': '8491'},
#   'away': {'name': 'Argentina', 'shortName': 'Argentina', 'id': '6706'},
#   'status': {'utcTime': '2026-07-15T19:00:00Z',
#    'timezone': 'UTC',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'round': 'bronze',
#   'roundName': 'Bronze Final',
#   'pageUrl': '/matches/francespain-vs-englandargentina/31zul098k#4653857',
#   'id': '4653857',
#   'home': {'name': 'France/Spain',
#    'shortName': 'France/Spain',
#    'id': '2075533'},
#   'away': {'name': 'England/Argentina',
#    'shortName': 'England/Argentina',
#    'id': '2076509'},
#   'status': {'utcTime': '2026-07-18T21:00:00Z',
#    'timezone': 'UTC',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'round': 'final',
#   'roundName': 'Final',
#   'pageUrl': '/matches/francespain-vs-englandargentina/31zul098k#4653858',
#   'id': '4653858',
#   'home': {'name': 'France/Spain',
#    'shortName': 'France/Spain',
#    'id': '2075533'},
#   'away': {'name': 'England/Argentina',
#    'shortName': 'England/Argentina',
#    'id': '2076509'},
#   'status': {'utcTime': '2026-07-19T19:00:00Z',
#    'timezone': 'UTC',
#    'started': False,
#    'cancelled': False,
#    'finished': False}}]
